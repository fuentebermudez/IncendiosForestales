# %%
import pandas as pd
import numpy as np
import time
import AEMET
import MODIS
import datetime
import time
import datetime
from datetime import date
import Utilidades
import csv

# %%
fires_meteo=pd.read_excel("../data/fires_join_metEstation.xlsx",encoding='latin-1')

# %%
# %%time
fire_meteo=[]
fires_meteo_test=fires_meteo[64533:]
n=64533
for fire in fires_meteo_test.iterrows():
    id_fire=str(fire[1]['id'])
    fecha_inicial=MODIS.format_modis_date(Utilidades.substract_days(fire[1]['fecha'],n_days=15))
    fecha_final=MODIS.format_modis_date(fire[1]['fecha'])
    lat=str(fire[1]['lat'])
    lng=str(fire[1]['lng'])
    id_estacion=fire[1]['ID_ESTACIO']
    if n%100==0:
        print(n)
    try:
        datos=MODIS.get_ndvi_serie(lat,lng,fecha_inicial,fecha_final)
    except:
        time.sleep(1)
        datos=np.nan
   
    valores=[n,datos]
    valores.append(id_fire)
        
        
    with open('D:\\borrar\\modis_3.txt', 'a',newline='') as myfile:
        wr = csv.writer(myfile, quoting=csv.QUOTE_NONNUMERIC)
        wr.writerow(valores)
            
    fire_meteo.append(valores)
    n=n+1
# Out:
# 64600
# 64700
# 64800
# 64900
# 65000
# 65100
# 65200
# 65300
# 65400
# 65500
# 65600
# 65700
# 65800
# 65900
# 66000
# 66100
# 66200
# 66300
# 66400
# 66500
# 66600
# 66700
# 66800
# 66900
# 67000
# 67100
# 67200
# 67300
# 67400
# 67500
# 67600
# 67700
# 67800
# 67900
# 68000
# 68100
# 68200
# 68300
# 68400
# 68500
# 68600
# 68700
# 68800
# 68900
# 69000
# 69100
# 69200
# 69300
# 69400
# 69500
# 69600
# 69700
# 69800
# 69900
# 70000
# 70100
# 70200
# 70300
# 70400
# 70500
# 70600
# 70700
# 70800
# 70900
# 71000
# 71100
# 71200
# 71300
# 71400
# 71500
# 71600
# 71700
# 71800
# 71900
# 72000
# 72100
# 72200
# 72300
# 72400
# 72500
# 72600
# 72700
# 72800
# 72900
# 73000
# 73100
# 73200
# 73300
# 73400
# 73500
# 73600
# 73700
# 73800
# 73900
# 74000
# 74100
# 74200
# 74300
# 74400
# 74500
# 74600
# 74700
# 74800
# 74900
# 75000
# 75100
# 75200
# 75300
# 75400
# 75500
# 75600
# 75700
# 75800
# 75900
# 76000
# 76100
# 76200
# 76300
# 76400
# 76500
# 76600
# 76700
# 76800
# 76900
# 77000
# 77100
# 77200
# 77300
# 77400
# 77500
# 77600
# 77700
# 77800
# 77900
# 78000
# 78100
# 78200
# 78300
# 78400
# 78500
# 78600
# 78700
# 78800
# 78900
# 79000
# 79100
# 79200
# 79300
# 79400
# 79500
# 79600
# 79700
# 79800
# 79900
# 80000
# 80100
# 80200
# 80300
# 80400
# 80500
# 80600
# 80700
# 80800
# 80900
# 81000
# 81100
# 81200
# 81300
# 81400
# 81500
# 81600
# 81700
# 81800
# 81900
# 82000
# 82100
# 82200
# 82300
# 82400
# 82500
# 82600
# Wall time: 7h 28min 51s
