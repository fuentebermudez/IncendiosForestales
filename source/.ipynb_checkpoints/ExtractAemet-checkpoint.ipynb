# %%
import pandas as pd
import numpy as np
import time
import AEMET
import MODIS
import datetime
import time
import datetime
from datetime import date
import Utilidades
import csv
# Out:
# 0.8076285544318859

# %%
token="eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJGdWVudGViZXJtdWRlekBnbWFpbC5jb20iLCJqdGkiOiI3MjMzMDA5Yi0zYmUwLTQzMTgtYWIxZC0yMzJmM2Y4YWQxNTYiLCJpc3MiOiJBRU1FVCIsImlhdCI6MTU2MDgwMTczMCwidXNlcklkIjoiNzIzMzAwOWItM2JlMC00MzE4LWFiMWQtMjMyZjNmOGFkMTU2Iiwicm9sZSI6IiJ9.N02GVYXuX9u-FIG5ljUktrDus4elnM-iVG7jthW-eg8"

# %%
fires_meteo=pd.read_csv("../data/incendios_reprocesar.csv",encoding='latin-1',error_bad_lines=False)
# Out:
# b'Skipping line 177: expected 34 fields, saw 35\nSkipping line 203: expected 34 fields, saw 35\nSkipping line 229: expected 34 fields, saw 35\nSkipping line 232: expected 34 fields, saw 35\nSkipping line 236: expected 34 fields, saw 35\nSkipping line 290: expected 34 fields, saw 35\nSkipping line 311: expected 34 fields, saw 35\nSkipping line 314: expected 34 fields, saw 35\nSkipping line 319: expected 34 fields, saw 35\nSkipping line 347: expected 34 fields, saw 35\nSkipping line 500: expected 34 fields, saw 35\nSkipping line 557: expected 34 fields, saw 35\nSkipping line 563: expected 34 fields, saw 35\nSkipping line 596: expected 34 fields, saw 35\nSkipping line 714: expected 34 fields, saw 35\nSkipping line 715: expected 34 fields, saw 35\nSkipping line 717: expected 34 fields, saw 35\nSkipping line 733: expected 34 fields, saw 35\nSkipping line 737: expected 34 fields, saw 35\nSkipping line 739: expected 34 fields, saw 35\nSkipping line 741: expected 34 fields, saw 35\nSkipping line 746: expected 34 fields, saw 35\nSkipping line 749: expected 34 fields, saw 35\nSkipping line 750: expected 34 fields, saw 35\nSkipping line 766: expected 34 fields, saw 35\nSkipping line 840: expected 34 fields, saw 35\nSkipping line 896: expected 34 fields, saw 35\nSkipping line 907: expected 34 fields, saw 35\nSkipping line 914: expected 34 fields, saw 35\nSkipping line 916: expected 34 fields, saw 35\nSkipping line 938: expected 34 fields, saw 35\nSkipping line 968: expected 34 fields, saw 35\nSkipping line 969: expected 34 fields, saw 35\nSkipping line 1010: expected 34 fields, saw 35\nSkipping line 1012: expected 34 fields, saw 35\nSkipping line 1016: expected 34 fields, saw 35\nSkipping line 1054: expected 34 fields, saw 35\nSkipping line 1059: expected 34 fields, saw 35\nSkipping line 1078: expected 34 fields, saw 35\nSkipping line 1114: expected 34 fields, saw 35\nSkipping line 1150: expected 34 fields, saw 35\nSkipping line 1157: expected 34 fields, saw 35\nSkipping line 1158: expected 34 fields, saw 35\nSkipping line 1173: expected 34 fields, saw 35\nSkipping line 1191: expected 34 fields, saw 35\nSkipping line 1192: expected 34 fields, saw 35\nSkipping line 1202: expected 34 fields, saw 35\nSkipping line 1206: expected 34 fields, saw 35\nSkipping line 1216: expected 34 fields, saw 35\nSkipping line 1229: expected 34 fields, saw 35\nSkipping line 1230: expected 34 fields, saw 35\nSkipping line 1232: expected 34 fields, saw 35\nSkipping line 1248: expected 34 fields, saw 35\nSkipping line 1294: expected 34 fields, saw 35\nSkipping line 1295: expected 34 fields, saw 35\nSkipping line 1306: expected 34 fields, saw 35\nSkipping line 1336: expected 34 fields, saw 35\nSkipping line 1355: expected 34 fields, saw 35\nSkipping line 1373: expected 34 fields, saw 35\nSkipping line 1384: expected 34 fields, saw 35\nSkipping line 1392: expected 34 fields, saw 35\nSkipping line 1402: expected 34 fields, saw 35\nSkipping line 1410: expected 34 fields, saw 35\nSkipping line 1416: expected 34 fields, saw 35\nSkipping line 1423: expected 34 fields, saw 35\nSkipping line 1425: expected 34 fields, saw 35\nSkipping line 1426: expected 34 fields, saw 35\nSkipping line 1429: expected 34 fields, saw 35\nSkipping line 1575: expected 34 fields, saw 35\nSkipping line 1580: expected 34 fields, saw 35\nSkipping line 1581: expected 34 fields, saw 35\nSkipping line 1591: expected 34 fields, saw 35\nSkipping line 1593: expected 34 fields, saw 35\nSkipping line 1612: expected 34 fields, saw 35\nSkipping line 1615: expected 34 fields, saw 35\nSkipping line 1622: expected 34 fields, saw 35\nSkipping line 1625: expected 34 fields, saw 35\nSkipping line 1626: expected 34 fields, saw 35\nSkipping line 1627: expected 34 fields, saw 35\nSkipping line 1628: expected 34 fields, saw 35\nSkipping line 1632: expected 34 fields, saw 35\nSkipping line 1636: expected 34 fields, saw 35\nSkipping line 1637: expected 34 fields, saw 35\nSkipping line 1639: expected 34 fields, saw 35\ ...
# c:\program files (x86)\python37-32\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (10,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
fires_meteo.shape
# Out:
# (48413, 34)

# %%
# %%time
fire_meteo=[]
fires_meteo_test=fires_meteo[30198:]
n=30198
for fire in fires_meteo_test.iterrows():
    id_fire=str(fire[1]['id'])
    fecha_inicial=Utilidades.substract_days(fire[1]['fecha'])
    fecha_final=fire[1]['fecha']
    id_estacion=fire[1]['ID_ESTACIO']
    try:
        #time.sleep(0.5)
        #print(fecha_inicial,fecha_final,id_estacion)
        if n%20==0:
            time.sleep(5)
        datos=AEMET.get_datos_meteorologicos(token,fecha_inicial,fecha_final,id_estacion)
    except:
        time.sleep(1)
        if n%10==0:
            time.sleep(5)
            
            
        datos=[]
        n=n+1
        
    if len(datos)>0:
        datos=datos.mean()
        try:
            altitud=datos.altitud
        except AttributeError:
            altitud=np.nan
        try:
            tmax=datos.tmax
        except:
            tmax=np.nan
        try:
            tmin=datos.tmin
        except:
            tmin=np.nan
        try:
            prec=datos.prec
        except AttributeError:
            prec=np.nan
        try:
            velmedia=datos.velmedia
        except:
            velmedia=np.nan
        try:
            racha=datos.racha
        except:
            racha=np.nan

        valores=[n,altitud,tmax,tmin,prec,velmedia,racha]
        valores.append(id_fire)
        
        
        with open('D:\\borrar\\meteo_reprocesar.txt', 'a',newline='') as myfile:
            wr = csv.writer(myfile, quoting=csv.QUOTE_NONNUMERIC)
            wr.writerow(valores)
            
        fire_meteo.append(valores)
        n=n+1

fire_meteo=pd.DataFrame(fire_meteo)
fire_meteo.to_csv('D:\\borrar\\meteo3.txt',index=False)
